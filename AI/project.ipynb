# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("dataset2.csv")

# %%
dataset = dataset[["koi_score","koi_steff_err2","koi_slogg","koi_slogg_err1","koi_slogg_err2","koi_srad","koi_srad_err1","koi_srad_err2","ra","dec","koi_kepmag"]]

# %%
dataset
# Out:
#       koi_score  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 0         1.000           -81.0      4.467           0.064          -0.096
# 1         0.969           -81.0      4.467           0.064          -0.096
# 2         0.000          -176.0      4.544           0.044          -0.176
# 3         0.000          -174.0      4.564           0.053          -0.168
# 4         1.000          -211.0      4.438           0.070          -0.210
# ...         ...             ...        ...             ...             ...
# 9559      0.000          -166.0      4.529           0.035          -0.196
# 9560      0.497          -220.0      4.444           0.056          -0.224
# 9561      0.021          -236.0      4.447           0.056          -0.224
# 9562      0.092          -128.0      2.992           0.030          -0.027
# 9563      0.000          -225.0      4.385           0.054          -0.216
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 1        0.927          0.105         -0.061  291.93423  48.141651      15.347
# 2        0.868          0.233         -0.078  297.00482  48.134129      15.436
# 3        0.791          0.201         -0.067  285.53461  48.285210      15.597
# 4        1.046          0.334         -0.133  288.75488  48.226200      15.509
# ...        ...            ...            ...        ...        ...         ...
# 9559     0.903          0.237         -0.079  297.18875  47.093819      14.082
# 9560     1.031          0.341         -0.114  286.50937  47.163219      14.757
# 9561     1.041          0.341         -0.114  294.16489  47.176281      15.385
# 9562     7.824          0.223         -1.896  296.76288  47.145142      10.998
# 9563     1.193          0.410         -0.137  297.00977  47.121021      14.826
#
# [9564 rows x 11 columns]

# %%
import seaborn as sns

dataset.plot.hist(y="koi_score")
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#       koi_score  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 24          NaN           -79.0      4.081           0.014          -0.014
# 75          NaN          -168.0      4.539           0.027          -0.275
# 99          NaN          -112.0      4.556           0.014          -0.094
# 123         NaN          -219.0      4.428           0.077          -0.272
# 143       1.000             NaN      4.603           0.011          -0.060
# ...         ...             ...        ...             ...             ...
# 9403      0.000             NaN      4.438             NaN             NaN
# 9406      0.235             NaN        NaN             NaN             NaN
# 9440      0.000             NaN      4.438             NaN             NaN
# 9501      0.207             NaN        NaN             NaN             NaN
# 9517      0.000             NaN        NaN             NaN             NaN
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 24       1.580          0.064         -0.064  292.27374  37.671558      12.394
# 75       0.878          0.333         -0.065  291.04480  51.321671      15.727
# 99       0.867          0.092         -0.034  285.28363  38.947281      15.403
# 123      0.990          0.377         -0.117  296.00699  40.295429      15.202
# 143      0.756          0.054         -0.027  294.20215  40.663410      15.208
# ...        ...            ...            ...        ...        ...         ...
# 9403     1.000            NaN            NaN  294.08633  46.131641      17.332
# 9406       NaN            NaN            NaN  292.16595  46.227631      14.703
# 9440     1.000            NaN            NaN  297.04431  49.970200      19.174
# 9501       NaN            NaN            NaN  291.26102  45.637470      10.555
# 9517       NaN            NaN            NaN  295.20798  46.786221      15.024
#
# [1672 rows x 11 columns]

# %%
dataset = dataset.dropna()

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop(['koi_score'],axis=1)
y = dataset['koi_score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 3061           -81.0      4.025           0.208          -0.112     1.525
# 5698          -200.0      3.888           0.560          -0.140     1.891
# 1234          -135.0      4.274           0.115          -0.115     1.299
# 5398          -305.0      4.162           0.128          -0.192     1.660
# 5996           -81.0      4.505           0.039          -0.097     0.888
# ...              ...        ...             ...             ...       ...
# 326           -121.0      2.472           0.156          -0.117    13.652
# 7569          -118.0      4.272           0.120          -0.120     1.292
# 4819           -81.0      4.453           0.076          -0.085     0.933
# 1316          -130.0      4.642           0.032          -0.052     0.666
# 5457          -307.0      4.013           0.273          -0.147     1.959
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag  \
# 3061          0.252         -0.378  293.72586  47.247040      13.037
# 5698          0.507         -0.942  294.91611  46.944977      12.829
# 1234          0.225         -0.184  290.09082  39.816990      13.470
# 5398          0.528         -0.352  300.19409  45.145741      13.930
# 5996          0.104         -0.052  282.86319  41.796680      14.320
# ...             ...            ...        ...        ...         ...
# 326           1.869         -4.361  289.09323  49.424484       6.974
# 7569          0.209         -0.209  295.40433  42.981422      11.472
# 4819          0.100         -0.073  295.51495  51.203739      14.732
# 1316          0.066         -0.054  286.25644  46.892670      14.708
# 5457          0.468         -0.643  299.24063  41.621681      17.719
#
#       koi_score
# 3061      0.269
# 5698      0.000
# 1234      1.000
# 5398      0.000
# 5996      0.968
# ...         ...
# 326       0.000
# 7569      1.000
# 4819      0.921
# 1316      0.000
# 5457      0.000
#
# [6313 rows x 11 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([0.6164439 , 0.31566165, 0.51102145, ..., 0.71523412, 0.72344471,
#        0.04991117])

# %%
y_lr_test_pred
# Out:
# array([0.54252793, 0.58221617, 0.24777767, ..., 0.37474478, 0.68083614,
#        0.311387  ])

# %% [markdown]
# # Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train,y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test,y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 0.19106838231928056

# %%
lr_train_r2
# Out:
# 0.1584517887073953

# %%
lr_test_mse
# Out:
# 0.19430873366418716

# %%
lr_test_r2
# Out:
# 0.15142411935812605
